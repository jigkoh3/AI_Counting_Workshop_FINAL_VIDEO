# %% [markdown]
# # Lab 2: YOLOv8 Training
# Train a YOLOv8 model to detect sacks.

# %%
# !pip install ultralytics
from ultralytics import YOLO
model = YOLO('yolov8n.pt')
model.train(data='dataset/data.yaml', epochs=50, imgsz=640)
