# %% [markdown]
# # Lab 3: Object Tracking and Counting
# Use Deep SORT and YOLOv8 to count sacks passing a line.

# %%
# install dependencies
# !pip install ultralytics opencv-python deep_sort_realtime
# ... (tracking logic will be in counting_with_tracking.py)
